# %% [markdown]
# # 02 特徵工程
# 計算只使用當下與過去資料的技術指標。

# %%
from src.data_loader import generate_mock_ohlcv
from src.features import add_features, feature_columns

features = add_features(generate_mock_ohlcv())
print(feature_columns(features))
display(features.tail())
