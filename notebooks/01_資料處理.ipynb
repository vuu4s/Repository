# %% [markdown]
# # 01 資料處理
# 使用可重現的 mock 台股分鐘 K 資料。

# %%
from src.data_loader import generate_mock_ohlcv

ohlcv = generate_mock_ohlcv(rows=2000, seed=42)
display(ohlcv.head())
display(ohlcv.describe())
